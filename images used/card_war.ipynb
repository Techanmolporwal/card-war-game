# %% [raw]
# from tkinter import *
# from PIL import ImageTk, Image
# from random import *
# from tkinter import font
# import pygame
# from pygame import mixer
# from tkinter import messagebox
#
# window=Tk()
# window.geometry('400x400')
# window.resizable(0,0)
# myfont=font.Font(family='Stencil Std',size=30)
# pygame.init()
# clock=pygame.time.Clock()
#
# chech_check=IntVar()
# #backcard
# backc= Image.open('yellow_back.png')
# backc= backc.resize((150, 200), Image.ANTIALIAS)
# bc= ImageTk.PhotoImage(backc)
#
# backu= Image.open('red_back.png')
# backu= backu.resize((150, 200), Image.ANTIALIAS)
# bu= ImageTk.PhotoImage(backu)
#
# total_card_comp=''
# total_card_user=''
#
#
# com_cards=[]
# user_cards=[]
# cards=['Two of heart 1','Two of diamond 1','Two of spade 1','Two of clubs 1','Three of heart 2',
#        'Three of diamond 2','Three of spade 2','Three of clubs 2','Four of heart 3',
#        'Four of diamond 3','Four of spade 3','Four of clubs 3','Five of hearts 4','Five of diamond 4','Five of spade 4',
#        'Five of clubs 4','Six of heart 5','Six of diamond 5','Six of spade 5','Six of clubs 5',
#        'Seven of hearts 6','Seven of diamond 6','Seven of spade 6','Seven of clubs 6','Eight of heart 7',
#        'Eight of diamond 7','Eight of spade 7','Eight of clubs 7','Nine of heart 8','Nine of diamond 8',
#        'Nine of spade 8','Nine of clubs 8','Ten of heart 9','Ten of diamond 9','Ten of spade 9',
#        'Ten of clubs 9','Jack of heart11','Jack of diamond11','Jack of spade11','Jack of clubs11',
#        'Queen of hearts12','Queen of diamond12','Queen of spade12','Queen of clubs12','king of heart13',
#        'King of diamond13','King of spade13','King of clubs13','Ace of heart14','Ace of diamond14',
#        'Ace of spade14','Ace of clubs14']
#
# d=sample(cards,26)
# com_cards.extend(d)
# user_cards.extend(cards)
# for datelement1 in com_cards :
#             if datelement1 in user_cards:
#                 user_cards.remove(datelement1)
# sc=0
# su=0
# total_amt_com=[]
# total_amt_user=[]
#
# comp_war_lis=sample(com_cards,5)
# user_war_lis=sample(user_cards,5)
# comp_war_ran=choice(comp_war_lis)
# user_war_ran=choice(user_war_lis)
# rank_war_com=comp_war_ran[len(comp_war_ran)-2:]
# rank_war_user=user_war_ran[len(user_war_ran)-2:]
# def front_page():
#     global com_cards
#     global user_cards
#     global cards
#     global sc
#     global su
#     global total_amt_com
#     global total_amt_user
#     global bc
#     global bu
#     global chech_check
#     name_alpha=name.get()
#     try:
#         if name_alpha.isnumeric():
#             messagebox.showinfo('showinfo','please enter only alphabets')
#         elif len(name_alpha)<3:
#             messagebox.showinfo('showinfo','name must be greater then 3 letter')
#         else:
#             inst=Toplevel()
#             mixer.music.stop()
#             inst.geometry('600x700')
#             inst.configure(bg='light goldenrod')
#             inst.resizable(0,0)
#             def move_fur():
#                 global com_cards
#                 global user_cards
#                 global cards
#                 global sc
#                 global su
#                 global total_amt_com
#                 global total_amt_user
#                 global bc
#                 global bu
#                 global chech_check
#                 get_check=chech_check.get()
#                 if get_check==0:
#                     messagebox.showinfo('showinfo','You must have to tick check box first')
#                 else:
#                     inst.destroy()
#                     window.destroy()
#                     root=Tk()
#                     global com_cards
#                     global user_cards
#                     global cards
#                     global sc
#                     global su
#                     global total_amt_com
#                     global total_amt_user
#                     global bc
#                     global bu
#                     root.geometry('1600x1200')
#                     root.configure(bg='black')
#                     root.resizable(0,0)
#                     pygame.init()
#                     clock=pygame.time.Clock()
#                     myfont=font.Font(family='Stencil Std',size=30)
#                     def play():
#                         global com_cards
#                         global user_cards
#                         global cards
#                         global sc
#                         global su
#                         global total_amt_com
#                         global total_amt_user
#                         global bc
#                         global bu
#                         print('inside a function')
#                         amount=my_entry.get()
#                         if amount.isalpha():
#                             messagebox.showinfo('showinfo','please enter only numbers')
#                         elif amount=='':
#                             messagebox.showinfo('showinfo','please ente Amount')
#                         elif ((int(amount))>500):
#                             heart2 = Image.open('2H.png')
#                             heart2 = heart2 .resize((150, 200), Image.ANTIALIAS)
#                             h22 = ImageTk.PhotoImage(heart2)
#                             #cards[0]=h22
#                             dimond2 = Image.open('2D.png')
#                             dimond2 = dimond2.resize((150, 200), Image.ANTIALIAS)
#                             d22 = ImageTk.PhotoImage(dimond2)
#                                 #cards[1]=d22
#                             spade2= Image.open('2S.png')
#                             spade2 = spade2.resize((150, 200), Image.ANTIALIAS)
#                             s22 = ImageTk.PhotoImage(spade2)
#                             #cards[2]=s22
#                             club2 = Image.open('2C.png')
#                             club2 = club2.resize((150, 200), Image.ANTIALIAS)
#                             c22 = ImageTk.PhotoImage(club2)
#                             #cards[3]=c22
#                             #3
#                             heart3 = Image.open('3H.png')
#                             heart3 = heart3 .resize((150, 200), Image.ANTIALIAS)
#                             h33 = ImageTk.PhotoImage(heart3)
#                             #cards[4]=h33
#                             dimond3 = Image.open('3D.png')
#                             dimond3 = dimond3.resize((150, 200), Image.ANTIALIAS)
#                             d33 = ImageTk.PhotoImage(dimond3)
#                             #cards[5]=d33
#                             spade3= Image.open('3S.png')
#                             spade3 = spade3.resize((150, 200), Image.ANTIALIAS)
#                             s33 = ImageTk.PhotoImage(spade3)
#                             #cards[6]=s33
#                             club3 = Image.open('3C.png')
#                             club3 = club3.resize((150, 200), Image.ANTIALIAS)
#                             c33 = ImageTk.PhotoImage(club3)
#                             #cards[7]=c33
#
#                             #4
#                             heart4 = Image.open('4H.png')
#                             heart4 = heart4 .resize((150, 200), Image.ANTIALIAS)
#                             h44 = ImageTk.PhotoImage(heart4)
#                             #cards[8]=h44
#                             dimond4 = Image.open('4D.png')
#                             dimond4 = dimond4.resize((150, 200), Image.ANTIALIAS)
#                             d44 = ImageTk.PhotoImage(dimond4)
#                             #cards[9]=d44
#                             spade4= Image.open('4S.png')
#                             spade4 = spade4.resize((150, 200), Image.ANTIALIAS)
#                             s44 = ImageTk.PhotoImage(spade4)
#                             #cards[10]=s44
#                             club4 = Image.open('4C.png')
#                             club4 = club4.resize((150, 200), Image.ANTIALIAS)
#                             c44 = ImageTk.PhotoImage(club4)
#                             #cards[11]=c44
#
#                             #5
#                             heart5= Image.open('5H.png')
#                             heart5= heart5.resize((150, 200), Image.ANTIALIAS)
#                             h55= ImageTk.PhotoImage(heart5)
#                             ###cards[12]=h55
#                             dimond5 = Image.open('5D.png')
#                             dimond5 = dimond5.resize((150, 200), Image.ANTIALIAS)
#                             d55 = ImageTk.PhotoImage(dimond5)
#                             ###cards[13]=d55
#                             spade5= Image.open('5S.png')
#                             spade5= spade5.resize((150, 200), Image.ANTIALIAS)
#                             s55 =ImageTk.PhotoImage(spade5)
#                             ###cards[14]=s55
#                             club5 = Image.open('5C.png')
#                             club5= club5.resize((150, 200), Image.ANTIALIAS)
#                             c55 = ImageTk.PhotoImage(club5)
#                             ###cards[15]=c55
#                             #6
#                             heart6= Image.open('6H.png')
#                             heart6= heart6.resize((150, 200), Image.ANTIALIAS)
#                             h66= ImageTk.PhotoImage(heart6)
#                             ##cards[16]= h66
#                             dimond6 = Image.open('6D.png')
#                             dimond6 = dimond6.resize((150, 200), Image.ANTIALIAS)
#                             d66 = ImageTk.PhotoImage(dimond6)
#                             ##cards[17]=d66
#                             spade6= Image.open('6S.png')
#                             spade6= spade6.resize((150, 200), Image.ANTIALIAS)
#                             s66= ImageTk.PhotoImage(spade6)
#                             ##cards[18]=s66
#                             club6 = Image.open('6C.png')
#                             club6=club6.resize((150, 200), Image.ANTIALIAS)
#                             c66 = ImageTk.PhotoImage(club6)
#                             ##cards[19]=c66
#
#                             #7
#                             heart7= Image.open('7H.png')
#                             heart7= heart7.resize((150, 200), Image.ANTIALIAS)
#                             h77= ImageTk.PhotoImage(heart7)
#                             #cards[20]=h77
#                             dimond7 = Image.open('7D.png')
#                             dimond7 = dimond7.resize((150, 200), Image.ANTIALIAS)
#                             d77 = ImageTk.PhotoImage(dimond7)
#                             #cards[21]= d77
#                             spade7= Image.open('7S.png')
#                             spade7= spade7.resize((150, 200), Image.ANTIALIAS)
#                             s77= ImageTk.PhotoImage(spade7)
#                             #cards[22]= s77
#                             club7 = Image.open('7C.png')
#                             club7=club7.resize((150, 200), Image.ANTIALIAS)
#                             c77 = ImageTk.PhotoImage(club7)
#                             #cards[23]=c77
#
#                             #8
#                             heart8= Image.open('8H.png')
#                             heart8= heart8.resize((150, 200), Image.ANTIALIAS)
#                             h88= ImageTk.PhotoImage(heart8)
#                             ###cards[24]=h88
#                             dimond8 = Image.open('8D.png')
#                             dimond8 = dimond8.resize((150, 200), Image.ANTIALIAS)
#                             d88 = ImageTk.PhotoImage(dimond8)
#                             ###cards[25]=d88
#                             spade8= Image.open('8S.png')
#                             spade8= spade8.resize((150, 200), Image.ANTIALIAS)
#                             s88= ImageTk.PhotoImage(spade8)
#                             ###cards[26]=s88
#                             club8 = Image.open('8C.png')
#                             club8=club8.resize((150, 200), Image.ANTIALIAS)
#                             c88 = ImageTk.PhotoImage(club8)
#                             ###cards[27]=c88
#
#                             #9
#                             heart9= Image.open('9H.png')
#                             heart9= heart9.resize((150, 200), Image.ANTIALIAS)
#                             h99= ImageTk.PhotoImage(heart9)
#                             ##cards[28]= h99
#                             dimond9 = Image.open('9D.png')
#                             dimond9= dimond9.resize((150, 200), Image.ANTIALIAS)
#                             d99 = ImageTk.PhotoImage(dimond9)
#                             ##cards[29]=d99
#                             spade9= Image.open('9S.png')
#                             spade9= spade9.resize((150, 200), Image.ANTIALIAS)
#                             s99= ImageTk.PhotoImage(spade9)
#                             ##cards[30]=s99
#                             club9 = Image.open('9C.png')
#                             club9=club8.resize((150, 200), Image.ANTIALIAS)
#                             c99= ImageTk.PhotoImage(club8)
#                             ##cards[31]=c99
#
#                             #10
#                             heart10= Image.open('10H.png')
#                             heart10= heart10.resize((150, 200), Image.ANTIALIAS)
#                             h100= ImageTk.PhotoImage(heart10)
#                             #cards[32]=h100
#                             dimond10 = Image.open('10D.png')
#                             dimond10 = dimond10.resize((150, 200), Image.ANTIALIAS)
#                             d100 = ImageTk.PhotoImage(dimond10)
#                             #cards[33]=d100
#                             spade10= Image.open('10S.png')
#                             spade10= spade10.resize((150, 200), Image.ANTIALIAS)
#                             s100= ImageTk.PhotoImage(spade10)
#                             #cards[34]=s100
#                             club10 = Image.open('10C.png')
#                             club10=club10.resize((150, 200), Image.ANTIALIAS)
#                             c100 = ImageTk.PhotoImage(club10)
#                             #cards[35]=c100
#
#
#                             #JACK
#                             heartJ= Image.open('JH.png')
#                             heartJ= heartJ.resize((150, 200), Image.ANTIALIAS)
#                             h1J= ImageTk.PhotoImage(heartJ)
#                             #cards[36]=h1J
#                             dimondJ = Image.open('JD.png')
#                             dimondJ = dimondJ.resize((150, 200), Image.ANTIALIAS)
#                             d1J= ImageTk.PhotoImage(dimondJ)
#                             #cards[37]=d1J
#                             spadeJ= Image.open('JS.png')
#                             spadeJ= spadeJ.resize((150, 200), Image.ANTIALIAS)
#                             s1J= ImageTk.PhotoImage(spadeJ)
#                             #cards[38]=s1J
#                             clubJ = Image.open('JC.png')
#                             clubJ=clubJ.resize((150, 200), Image.ANTIALIAS)
#                             c1J = ImageTk.PhotoImage(clubJ)
#                             #cards[39]=c1J
#
#                             #QUEEN
#                             heartQ= Image.open('QH.png')
#                             heartQ= heartQ.resize((150, 200), Image.ANTIALIAS)
#                             h1Q= ImageTk.PhotoImage(heartQ)
#                             #cards[40]= h1Q
#                             dimondQ = Image.open('QD.png')
#                             dimondQ = dimondQ.resize((150, 200), Image.ANTIALIAS)
#                             d1Q= ImageTk.PhotoImage(dimondQ)
#                             #cards[41]=d1Q
#                             spadeQ= Image.open('QS.png')
#                             spadeQ= spadeQ.resize((150, 200), Image.ANTIALIAS)
#                             s1Q= ImageTk.PhotoImage(spadeQ)
#                             #cards[42]=s1Q
#                             clubQ = Image.open('QC.png')
#                             clubQ=clubQ.resize((150, 200), Image.ANTIALIAS)
#                             c1Q = ImageTk.PhotoImage(clubQ)
#                             #cards[43]=c1Q
#
#                             #KING
#                             heartK= Image.open('KH.png')
#                             heartK= heartK.resize((150, 200), Image.ANTIALIAS)
#                             h1K= ImageTk.PhotoImage(heartK)
#                             #cards[44]=h1K
#                             dimondK = Image.open('KD.png')
#                             dimondK = dimondK.resize((150, 200), Image.ANTIALIAS)
#                             d1K= ImageTk.PhotoImage(dimondK)
#                             #cards[45]=d1K
#                             spadeK= Image.open('KS.png')
#                             spadeK= spadeK.resize((150, 200), Image.ANTIALIAS)
#                             s1K= ImageTk.PhotoImage(spadeK)
#                             #cards[46]=s1K
#                             clubK = Image.open('KC.png')
#                             clubK=clubK.resize((150, 200), Image.ANTIALIAS)
#                             c1K = ImageTk.PhotoImage(clubK)
#                             #cards[47]=c1K
#
#                             #ace
#                             heartA= Image.open('AH.png')
#                             heartA= heartA.resize((150, 200), Image.ANTIALIAS)
#                             h1A= ImageTk.PhotoImage(heartA)
#                             #cards[48]=h1A
#                             dimondA = Image.open('AD.png')
#                             dimondA = dimondA.resize((150, 200), Image.ANTIALIAS)
#                             d1A= ImageTk.PhotoImage(dimondA)
#                             #cards[49]=d1A
#                             spadeA= Image.open('AS.png')
#                             spadeA= spadeA.resize((150, 200), Image.ANTIALIAS)
#                             s1A= ImageTk.PhotoImage(spadeA)
#                             #cards[50]=s1A
#                             clubA = Image.open('AC.png')
#                             clubA=clubA.resize((150, 200), Image.ANTIALIAS)
#                             c1A = ImageTk.PhotoImage(clubA)
#
#
#                             com_rand=choice(com_cards)
#                             user_rand=choice(user_cards)
#                             rank_com=int(com_rand[len(com_rand)-2:])
#                             rank_user=int(user_rand[len(user_rand)-2:])
#                             comp_card_size=com_rand[:len(com_rand)-1]
#                             user_card_size=user_rand[:len(user_rand)-1]
#                             comp_cardname=Label(root,text=comp_card_size,fg='black',bg='light goldenrod')
#                             comp_cardname.grid(row=4,column=1,pady=40,padx=10,ipadx=20,ipady=10)
#                             user_cardname=Label(root,text=user_card_size,fg='black',bg='light goldenrod')
#                             user_cardname.grid(row=4,column=3,pady=40,padx=10,ipadx=20,ipady=10)
#
#                             if rank_com>rank_user:
#                                 com_win='COMPUTER WINS!!!:₹{}'.format(amount)
#                                 total_amt_com.append(amount)
#                                 anounce=Label(root,text=com_win,bg='gray',fg='black',font=myfont)
#                                 anounce.grid(row=6,column=2,ipadx=30,ipady=15)
#                                 sc+=1
#
#                                 compc=Label(root,text=sc,bg='black',fg='light goldenrod',font=myfont)
#                                 compc.grid(row=6,column=1,padx=40,pady=10)
#                                 userc=Label(root,text=su,bg='black',fg='light goldenrod',font=myfont)
#                                 userc.grid(row=6,column=3,padx=40,pady=10)
#                                 if com_rand in com_cards:
#                                     if com_rand=='Two of heart 1':
#                                         com_rand=h22
#                                     elif(com_rand=='Two of diamond 1'):
#                                         com_rand=d22
#                                     elif(com_rand=='Two of spade 1'):
#                                         com_rand=s22
#                                     elif(com_rand=='Two of clubs 1'):
#                                         com_rand=c22
#                                     elif(com_rand=='Three of heart 2'):
#                                         com_rand=h33
#                                     elif(com_rand=='Three of diamond 2'):
#                                         com_rand=d33
#                                     elif(com_rand=='Three of spade 2'):
#                                         com_rand=s33
#                                     elif(com_rand=='Three of clubs 2'):
#                                         com_rand=c33
#                                     elif(com_rand=='Four of heart 3'):
#                                         com_rand=h44
#                                     elif(com_rand=='Four of diamond 3'):
#                                         com_rand=d44
#                                     elif(com_rand=='Four of spade 3'):
#                                         com_rand=s44
#                                     elif(com_rand=='Four of clubs 3'):
#                                         com_rand=c44
#                                     elif(com_rand=='Five of hearts 4'):
#                                         com_rand=h55
#                                     elif(com_rand=='Five of diamond 4'):
#                                         com_rand=d55
#                                     elif(com_rand=='Five of spade 4'):
#                                         com_rand=s55
#                                     elif(com_rand=='Five of clubs 4'):
#                                         com_rand=c55
#                                     elif(com_rand=='Six of heart 5'):
#                                         com_rand=h66
#                                     elif(com_rand=='Six of diamond 5'):
#                                         com_rand=d66
#                                     elif(com_rand=='Six of spade 5'):
#                                         com_rand=s66
#                                     elif(com_rand=='Six of clubs 5'):
#                                         com_rand=c66
#                                     elif(com_rand=='Seven of hearts 6'):
#                                         com_rand=h77
#                                     elif(com_rand=='Seven of diamond 6'):
#                                         com_rand=d77
#                                     elif(com_rand=='Seven of spade 6'):
#                                         com_rand=s77
#                                     elif(com_rand=='Seven of clubs 6'):
#                                         com_rand=c77
#                                     elif(com_rand=='Eight of heart 7'):
#                                         com_rand=h88
#                                     elif(com_rand=='Eight of diamond 7'):
#                                         com_rand=d88
#                                     elif(com_rand=='Eight of spade 7'):
#                                         com_rand=s88
#                                     elif(com_rand=='Eight of clubs 7'):
#                                         com_rand=c88
#                                     elif(com_rand=='Nine of heart 8'):
#                                         com_rand=h99
#                                     elif(com_rand=='Nine of diamond 8'):
#                                         com_rand=d88
#                                     elif(com_rand=='Nine of spade 8'):
#                                         com_rand=s99
#                                     elif(com_rand=='Nine of clubs 8'):
#                                         com_rand=c99
#                                     elif(com_rand=='Ten of heart 9'):
#                                         com_rand=h100
#                                     elif(com_rand=='Ten of diamond 9'):
#                                         com_rand=d100
#                                     elif(com_rand=='Ten of spade 9'):
#                                         com_rand=s100
#                                     elif(com_rand=='Ten of clubs 9'):
#                                         com_rand=c100
#                                     elif(com_rand=='Jack of heart11'):
#                                         com_rand=h1J
#                                     elif(com_rand=='Jack of diamond11'):
#                                         com_rand=d1J
#                                     elif(com_rand=='Jack of spade11'):
#                                         com_rand=s1J
#                                     elif(com_rand=='Jack of clubs11'):
#                                         com_rand=c1J
#                                     elif(com_rand=='Queen of hearts12'):
#                                         com_rand=h1Q
#                                     elif(com_rand=='Queen of diamond12'):
#                                         com_rand=d1Q
#                                     elif(com_rand=='Queen of spade12'):
#                                         com_rand=s1Q
#                                     elif(com_rand=='Queen of clubs12'):
#                                         com_rand=c1Q
#                                     elif(com_rand=='king of heart13'):
#                                         com_rand=h1K
#                                     elif(com_rand=='King of diamond13'):
#                                         com_rand=d1K
#                                     elif(com_rand=='King of spade13'):
#                                         com_rand=s1K
#                                     elif(com_rand=='King of clubs13'):
#                                         com_rand=c1K
#                                     elif(com_rand=='Ace of heart14'):
#                                         com_rand=h1A
#                                     elif(com_rand=='Ace of diamond14'):
#                                         com_rand=d1A
#                                     elif(com_rand=='Ace of spade14'):
#                                         com_rand=s1A
#                                     elif(com_rand=='Ace of clubs14'):
#                                         com_rand=c1A
#                                 if user_rand in user_cards:
#                                     if user_rand=='Two of heart 1':
#                                         user_rand=h22
#                                     elif(user_rand=='Two of diamond 1'):
#                                         user_rand=d22
#                                     elif(user_rand=='Two of spade 1'):
#                                         user_rand=s22
#                                     elif(user_rand=='Two of clubs 1'):
#                                         user_rand=c22
#                                     elif(user_rand=='Three of heart 2'):
#                                         user_rand=h33
#                                     elif(user_rand=='Three of diamond 2'):
#                                         user_rand=d33
#                                     elif(user_rand=='Three of spade 2'):
#                                         user_rand=s33
#                                     elif(user_rand=='Three of clubs 2'):
#                                         user_rand=c33
#                                     elif(user_rand=='Four of heart 3'):
#                                         user_rand=h44
#                                     elif(user_rand=='Four of diamond 3'):
#                                         user_rand=d44
#                                     elif(user_rand=='Four of spade 3'):
#                                         user_rand=s44
#                                     elif(user_rand=='Four of clubs 3'):
#                                         user_rand=c44
#                                     elif(user_rand=='Five of hearts 4'):
#                                         user_rand=h55
#                                     elif(user_rand=='Five of diamond 4'):
#                                         user_rand=d55
#                                     elif(user_rand=='Five of spade 4'):
#                                         user_rand=s55
#                                     elif(user_rand=='Five of clubs 4'):
#                                         user_rand=c55
#                                     elif(user_rand=='Six of heart 5'):
#                                         user_rand=h66
#                                     elif(user_rand=='Six of diamond 5'):
#                                         user_rand=d66
#                                     elif(user_rand=='Six of spade 5'):
#                                         user_rand=s66
#                                     elif(user_rand=='Six of clubs 5'):
#                                         user_rand=c66
#                                     elif(user_rand=='Seven of hearts 6'):
#                                         user_rand=h77
#                                     elif(user_rand=='Seven of diamond 6'):
#                                         user_rand=d77
#                                     elif(user_rand=='Seven of spade 6'):
#                                         user_rand=s77
#                                     elif(user_rand=='Seven of clubs 6'):
#                                         user_rand=c77
#                                     elif(user_rand=='Eight of heart 7'):
#                                         user_rand=h88
#                                     elif(user_rand=='Eight of diamond 7'):
#                                         user_rand=d88
#                                     elif(user_rand=='Eight of spade 7'):
#                                         user_rand=s88
#                                     elif(user_rand=='Eight of clubs 7'):
#                                         user_rand=c88
#                                     elif(user_rand=='Nine of heart 8'):
#                                         user_rand=h99
#                                     elif(user_rand=='Nine of diamond 8'):
#                                         user_rand=d88
#                                     elif(user_rand=='Nine of spade 8'):
#                                         user_rand=s99
#                                     elif(user_rand=='Nine of clubs 8'):
#                                         user_rand=c99
#                                     elif(user_rand=='Ten of heart 9'):
#                                         user_rand=h100
#                                     elif(user_rand=='Ten of diamond 9'):
#                                         user_rand=d100
#                                     elif(user_rand=='Ten of spade 9'):
#                                         user_rand=s100
#                                     elif(user_rand=='Ten of clubs 9'):
#                                         user_rand=c100
#                                     elif(user_rand=='Jack of heart11'):
#                                         user_rand=h1J
#                                     elif(user_rand=='Jack of diamond11'):
#                                         user_rand=d1J
#                                     elif(user_rand=='Jack of spade11'):
#                                         user_rand=s1J
#                                     elif(user_rand=='Jack of clubs11'):
#                                         user_rand=c1J
#                                     elif(user_rand=='Queen of hearts12'):
#                                         user_rand=h1Q
#                                     elif(user_rand=='Queen of diamond12'):
#                                         user_rand=d1Q
#                                     elif(user_rand=='Queen of spade12'):
#                                         user_rand=s1Q
#                                     elif(user_rand=='Queen of clubs12'):
#                                         user_rand=c1Q
#                                     elif(user_rand=='king of heart13'):
#                                         user_rand=h1K
#                                     elif(user_rand=='King of diamond13'):
#                                         user_rand=d1K
#                                     elif(user_rand=='King of spade13'):
#                                         user_rand=s1K
#                                     elif(user_rand=='King of clubs13'):
#                                         user_rand=c1K
#                                     elif(user_rand=='Ace of heart14'):
#                                         user_rand=h1A
#                                     elif(user_rand=='Ace of diamond14'):
#                                         user_rand=d1A
#                                     elif(user_rand=='Ace of spade14'):
#                                         user_rand=s1A
#                                     elif(user_rand=='Ace of clubs14'):
#                                         user_rand=c1A
#
#
#                                 comp1 = Label(root,image =com_rand)
#                                 comp1.grid(row=3,column=1,)
#                                 user1 = Label(root,image =user_rand)
#                                 user1.grid(row=3,column=3,)
#                                 user_cards.remove(com_rand)
#                                 #com_cards.append(com_rand)
#
#
#                             elif (rank_com==rank_user):
#                                 anounce=Label(root,text='    WAR!!!!!!!!!!!!!!   ',bg='gray',fg='black',font=myfont)
#                                 anounce.grid(row=6,column=2,ipadx=30,ipady=15)
#
#                                 if com_rand in com_cards:
#                                     if com_rand=='Two of heart 1':
#                                         com_rand=h22
#                                     elif(com_rand=='Two of diamond 1'):
#                                         com_rand=d22
#                                     elif(com_rand=='Two of spade 1'):
#                                         com_rand=s22
#                                     elif(com_rand=='Two of clubs 1'):
#                                         com_rand=c22
#                                     elif(com_rand=='Three of heart 2'):
#                                         com_rand=h33
#                                     elif(com_rand=='Three of diamond 2'):
#                                         com_rand=d33
#                                     elif(com_rand=='Three of spade 2'):
#                                         com_rand=s33
#                                     elif(com_rand=='Three of clubs 2'):
#                                         com_rand=c33
#                                     elif(com_rand=='Four of heart 3'):
#                                         com_rand=h44
#                                     elif(com_rand=='Four of diamond 3'):
#                                         com_rand=d44
#                                     elif(com_rand=='Four of spade 3'):
#                                         com_rand=s44
#                                     elif(com_rand=='Four of clubs 3'):
#                                         com_rand=c44
#                                     elif(com_rand=='Five of hearts 4'):
#                                         com_rand=h55
#                                     elif(com_rand=='Five of diamond 4'):
#                                         com_rand=d55
#                                     elif(com_rand=='Five of spade 4'):
#                                         com_rand=s55
#                                     elif(com_rand=='Five of clubs 4'):
#                                         com_rand=c55
#                                     elif(com_rand=='Six of heart 5'):
#                                         com_rand=h66
#                                     elif(com_rand=='Six of diamond 5'):
#                                         com_rand=d66
#                                     elif(com_rand=='Six of spade 5'):
#                                         com_rand=s66
#                                     elif(com_rand=='Six of clubs 5'):
#                                         com_rand=c66
#                                     elif(com_rand=='Seven of hearts 6'):
#                                         com_rand=h77
#                                     elif(com_rand=='Seven of diamond 6'):
#                                         com_rand=d77
#                                     elif(com_rand=='Seven of spade 6'):
#                                         com_rand=s77
#                                     elif(com_rand=='Seven of clubs 6'):
#                                         com_rand=c77
#                                     elif(com_rand=='Eight of heart 7'):
#                                         com_rand=h88
#                                     elif(com_rand=='Eight of diamond 7'):
#                                         com_rand=d88
#                                     elif(com_rand=='Eight of spade 7'):
#                                         com_rand=s88
#                                     elif(com_rand=='Eight of clubs 7'):
#                                         com_rand=c88
#                                     elif(com_rand=='Nine of heart 8'):
#                                         com_rand=h99
#                                     elif(com_rand=='Nine of diamond 8'):
#                                         com_rand=d88
#                                     elif(com_rand=='Nine of spade 8'):
#                                         com_rand=s99
#                                     elif(com_rand=='Nine of clubs 8'):
#                                         com_rand=c99
#                                     elif(com_rand=='Ten of heart 9'):
#                                         com_rand=h100
#                                     elif(com_rand=='Ten of diamond 9'):
#                                         com_rand=d100
#                                     elif(com_rand=='Ten of spade 9'):
#                                         com_rand=s100
#                                     elif(com_rand=='Ten of clubs 9'):
#                                         com_rand=c100
#                                     elif(com_rand=='Jack of heart11'):
#                                         com_rand=h1J
#                                     elif(com_rand=='Jack of diamond11'):
#                                         com_rand=d1J
#                                     elif(com_rand=='Jack of spade11'):
#                                         com_rand=s1J
#                                     elif(com_rand=='Jack of clubs11'):
#                                         com_rand=c1J
#                                     elif(com_rand=='Queen of hearts12'):
#                                         com_rand=h1Q
#                                     elif(com_rand=='Queen of diamond12'):
#                                         com_rand=d1Q
#                                     elif(com_rand=='Queen of spade12'):
#                                         com_rand=s1Q
#                                     elif(com_rand=='Queen of clubs12'):
#                                         com_rand=c1Q
#                                     elif(com_rand=='king of heart13'):
#                                         com_rand=h1K
#                                     elif(com_rand=='King of diamond13'):
#                                         com_rand=d1K
#                                     elif(com_rand=='King of spade13'):
#                                         com_rand=s1K
#                                     elif(com_rand=='King of clubs13'):
#                                         com_rand=c1K
#                                     elif(com_rand=='Ace of heart14'):
#                                         com_rand=h1A
#                                     elif(com_rand=='Ace of diamond14'):
#                                         com_rand=d1A
#                                     elif(com_rand=='Ace of spade14'):
#                                         com_rand=s1A
#                                     elif(com_rand=='Ace of clubs14'):
#                                         com_rand=c1A
#                                 if user_rand in user_cards:
#                                     if user_rand=='Two of heart 1':
#                                         user_rand=h22
#                                     elif(user_rand=='Two of diamond 1'):
#                                         user_rand=d22
#                                     elif(user_rand=='Two of spade 1'):
#                                         user_rand=s22
#                                     elif(user_rand=='Two of clubs 1'):
#                                         user_rand=c22
#                                     elif(user_rand=='Three of heart 2'):
#                                         user_rand=h33
#                                     elif(user_rand=='Three of diamond 2'):
#                                         user_rand=d33
#                                     elif(user_rand=='Three of spade 2'):
#                                         user_rand=s33
#                                     elif(user_rand=='Three of clubs 2'):
#                                         user_rand=c33
#                                     elif(user_rand=='Four of heart 3'):
#                                         user_rand=h44
#                                     elif(user_rand=='Four of diamond 3'):
#                                         user_rand=d44
#                                     elif(user_rand=='Four of spade 3'):
#                                         user_rand=s44
#                                     elif(user_rand=='Four of clubs 3'):
#                                         user_rand=c44
#                                     elif(user_rand=='Five of hearts 4'):
#                                         user_rand=h55
#                                     elif(user_rand=='Five of diamond 4'):
#                                         user_rand=d55
#                                     elif(user_rand=='Five of spade 4'):
#                                         user_rand=s55
#                                     elif(user_rand=='Five of clubs 4'):
#                                         user_rand=c55
#                                     elif(user_rand=='Six of heart 5'):
#                                         user_rand=h66
#                                     elif(user_rand=='Six of diamond 5'):
#                                         user_rand=d66
#                                     elif(user_rand=='Six of spade 5'):
#                                         user_rand=s66
#                                     elif(user_rand=='Six of clubs 5'):
#                                         user_rand=c66
#                                     elif(user_rand=='Seven of hearts 6'):
#                                         user_rand=h77
#                                     elif(user_rand=='Seven of diamond 6'):
#                                         user_rand=d77
#                                     elif(user_rand=='Seven of spade 6'):
#                                         user_rand=s77
#                                     elif(user_rand=='Seven of clubs 6'):
#                                         user_rand=c77
#                                     elif(user_rand=='Eight of heart 7'):
#                                         user_rand=h88
#                                     elif(user_rand=='Eight of diamond 7'):
#                                         user_rand=d88
#                                     elif(user_rand=='Eight of spade 7'):
#                                         user_rand=s88
#                                     elif(user_rand=='Eight of clubs 7'):
#                                         user_rand=c88
#                                     elif(user_rand=='Nine of heart 8'):
#                                         user_rand=h99
#                                     elif(user_rand=='Nine of diamond 8'):
#                                         user_rand=d88
#                                     elif(user_rand=='Nine of spade 8'):
#                                         user_rand=s99
#                                     elif(user_rand=='Nine of clubs 8'):
#                                         user_rand=c99
#                                     elif(user_rand=='Ten of heart 9'):
#                                         user_rand=h100
#                                     elif(user_rand=='Ten of diamond 9'):
#                                         user_rand=d100
#                                     elif(user_rand=='Ten of spade 9'):
#                                         user_rand=s100
#                                     elif(user_rand=='Ten of clubs 9'):
#                                         user_rand=c100
#                                     elif(user_rand=='Jack of heart11'):
#                                         user_rand=h1J
#                                     elif(user_rand=='Jack of diamond11'):
#                                         user_rand=d1J
#                                     elif(user_rand=='Jack of spade11'):
#                                         user_rand=s1J
#                                     elif(user_rand=='Jack of clubs11'):
#                                         user_rand=c1J
#                                     elif(user_rand=='Queen of hearts12'):
#                                         user_rand=h1Q
#                                     elif(user_rand=='Queen of diamond12'):
#                                         user_rand=d1Q
#                                     elif(user_rand=='Queen of spade12'):
#                                         user_rand=s1Q
#                                     elif(user_rand=='Queen of clubs12'):
#                                         user_rand=c1Q
#                                     elif(user_rand=='king of heart13'):
#                                         user_rand=h1K
#                                     elif(user_rand=='King of diamond13'):
#                                         user_rand=d1K
#                                     elif(user_rand=='King of spade13'):
#                                         user_rand=s1K
#                                     elif(user_rand=='King of clubs13'):
#                                         user_rand=c1K
#                                     elif(user_rand=='Ace of heart14'):
#                                         user_rand=h1A
#                                     elif(user_rand=='Ace of diamond14'):
#                                         user_rand=d1A
#                                     elif(user_rand=='Ace of spade14'):
#                                         user_rand=s1A
#                                     elif(user_rand=='Ace of clubs14'):
#                                         user_rand=c1A
#                                 comp_card_size=com_rand[:len(com_rand)-1]
#                                 user_card_size=user_rand[:len(user_rand)-1]
#                                 comp_cardname=Label(root,text=comp_card_size,fg='black',bg='light goldenrod')
#                                 comp_cardname.grid(row=4,column=1,pady=40,padx=10,ipadx=20,ipady=10)
#                                 user_cardname=Label(root,text=user_card_size,fg='black',bg='light goldenrod')
#                                 user_cardname.grid(row=4,column=3,pady=40,padx=10,ipadx=20,ipady=10)
#                                 comp1 = Label(root,image=com_rand,)
#                                 comp1.grid(row=3,column=1,)
#                                 user1 = Label(root,image =user_rand,)
#                                 user1.grid(row=3,column=3,)
#                                 warwind=Toplevel()
#                                 warwind.geometry('800x450')
#                                 warwind.configure(bg='black')
#                                 warwind.resizable(0,0)
#
#
#                                 def war_play():
#                                     global com_cards
#                                     global user_cards
#                                     global cards
#                                     global sc
#                                     global su
#                                     global total_amt_com
#                                     global total_amt_user
#                                     global bc
#                                     global bu
#                                     global chech_check
#                                     global comp_war_lis
#                                     global user_war_lis
#                                     global comp_war_ran
#                                     global user_war_ran
#                                     global rank_war_com
#                                     global rank_war_user
#                                     if int(rank_war_com)>int(rank_war_user):
#                                         print('winner of the war round is computer')
#                                         comp_size=comp_war_ran[:len(comp_war_ran)-1]
#                                         user_size=user_war_ran[:len(user_war_ran)-1]
#                                         comp_name=Label(warwind,text=comp_size,fg='black',bg='light goldenrod')
#                                         comp_name.grid(row=3,column=1,pady=40,padx=10,ipadx=20,ipady=10)
#                                         user_name=Label(warwind,text=user_size,fg='black',bg='light goldenrod')
#                                         user_name.grid(row=3,column=3,pady=40,padx=10,ipadx=20,ipady=10)
#                                         messagebox.showinfo('showinfo','You lose all your win amount till now')
#                                         warwind.destroy()
#                                         total_amt_user=[0]
#
#                                     elif (int(rank_war_com)==int(rank_war_user)):
#                                         print('war is tie we make side all 5 cards of both player')
#                                         comp_size=comp_war_ran[:len(comp_war_ran)-1]
#                                         user_size=user_war_ran[:len(user_war_ran)-1]
#                                         comp_name=Label(warwind,text=comp_size,fg='black',bg='light goldenrod')
#                                         comp_name.grid(row=3,column=1,pady=40,padx=10,ipadx=20,ipady=10)
#                                         user_name=Label(warwind,text=user_size,fg='black',bg='light goldenrod')
#                                         user_name.grid(row=3,column=3,pady=40,padx=10,ipadx=20,ipady=10)
#                                         messagebox.showinfo('showinfo','Neither Computer Wins money Neither you match is tie play one more turn')
#                                         warwind.destroy()
#                                     else:
#                                         comp_size=comp_war_ran[:len(comp_war_ran)-1]
#                                         user_size=user_war_ran[:len(user_war_ran)-1]
#                                         comp_name=Label(warwind,text=comp_size,fg='black',bg='light goldenrod')
#                                         comp_name.grid(row=3,column=1,pady=40,padx=10,ipadx=20,ipady=10)
#                                         user_name=Label(warwind,text=user_size,fg='black',bg='light goldenrod')
#                                         user_name.grid(row=3,column=3,pady=40,padx=10,ipadx=20,ipady=10)
#
#                                         allamount=Toplevel()
#                                         allamount.geometry('450x450')
#                                         allamount.configure(bg='dim gray')
#                                         allamount.resizable(0,0)
#                                         def wallet_rq():
#                                             global total_amt_com
#                                             global total_amt_user
#                                             total_amt_user.extend(total_amt_com)
#                                             total_amt_com=[0]
#                                             allamount.destroy()
#                                             warwind.destroy()
#
#                                         all_amt_png= Image.open('allamtwin.png')
#                                         all_amt_png= all_amt_png.resize((200, 250), Image.ANTIALIAS)
#                                         all_amt_png_img= ImageTk.PhotoImage(all_amt_png)
#                                         all_amt_label1=Label(allamount,image=all_amt_png_img,bg='dim gray')
#                                         all_amt_label1.grid(row=1,column=2)
#                                         all_amt_label2=Label(allamount,text='You Win all the Amount \n you lose till now',font=myfont,bg='dim gray',fg='light goldenrod')
#                                         all_amt_label2.grid(row=2,column=2,padx=10)
#                                         button_war_win=Button(allamount,text='Add Amount To Wallet',bg='light goldenrod',fg='black',command=wallet_rq)
#                                         button_war_win.grid(row=3,column=2)
#                                         allamount.mainloop()
#
#
#                                 lab_war =Label(warwind,text='WAR!!!!',bg='gray',fg='black',font=myfont)
#                                 lab_war.grid(row=1,column=2,pady=10)
#                                 com = Label(warwind,image =bc)
#                                 com.grid(row=2,column=1,padx=20)
#                                 use = Label(warwind,image =bu)
#                                 use.grid(row=2,column=3,)
#                                 button_bor=Frame(warwind,highlightbackground='white',highlightthickness=4,bd=0)
#                                 buto=Button(button_bor,text='Show War Cards',bg='light goldenrod',fg='black',font=myfont,command=war_play)
#                                 buto.grid()
#                                 button_bor.grid(row=3,column=2,pady=20,padx=30)
#                                 warwind.mainloop()
#
#                             else:
#                                 user_win='USER WINS!!!!!!!:₹{}'.format(amount)
#                                 total_amt_user.append(int(amount))
#                                 anounce=Label(root,text=user_win,bg='gray',fg='black',font=myfont)
#                                 anounce.grid(row=6,column=2,ipadx=30,ipady=15)
#                                 print(user_rand)
#                                 print('User wins')
#                                 print('user liste:',user_cards)
#                                 print('comp liste:',com_cards)
#
#                                 su+=1
#                                 compc=Label(root,text=sc,bg='black',fg='light goldenrod',font=myfont)
#                                 compc.grid(row=6,column=1,padx=40,pady=10)
#                                 userc=Label(root,text=su,bg='black',fg='light goldenrod',font=myfont)
#                                 userc.grid(row=6,column=3,padx=40,pady=10)
#
#                                 if com_rand in com_cards:
#                                     if com_rand=='Two of heart 1':
#                                         com_rand=h22
#                                     elif(com_rand=='Two of diamond 1'):
#                                         com_rand=d22
#                                     elif(com_rand=='Two of spade 1'):
#                                         com_rand=s22
#                                     elif(com_rand=='Two of clubs 1'):
#                                         com_rand=c22
#                                     elif(com_rand=='Three of heart 2'):
#                                         com_rand=h33
#                                     elif(com_rand=='Three of diamond 2'):
#                                         com_rand=d33
#                                     elif(com_rand=='Three of spade 2'):
#                                         com_rand=s33
#                                     elif(com_rand=='Three of clubs 2'):
#                                         com_rand=c33
#                                     elif(com_rand=='Four of heart 3'):
#                                         com_rand=h44
#                                     elif(com_rand=='Four of diamond 3'):
#                                         com_rand=d44
#                                     elif(com_rand=='Four of spade 3'):
#                                         com_rand=s44
#                                     elif(com_rand=='Four of clubs 3'):
#                                         com_rand=c44
#                                     elif(com_rand=='Five of hearts 4'):
#                                         com_rand=h55
#                                     elif(com_rand=='Five of diamond 4'):
#                                         com_rand=d55
#                                     elif(com_rand=='Five of spade 4'):
#                                         com_rand=s55
#                                     elif(com_rand=='Five of clubs 4'):
#                                         com_rand=c55
#                                     elif(com_rand=='Six of heart 5'):
#                                         com_rand=h66
#                                     elif(com_rand=='Six of diamond 5'):
#                                         com_rand=d66
#                                     elif(com_rand=='Six of spade 5'):
#                                         com_rand=s66
#                                     elif(com_rand=='Six of clubs 5'):
#                                         com_rand=c66
#                                     elif(com_rand=='Seven of hearts 6'):
#                                         com_rand=h77
#                                     elif(com_rand=='Seven of diamond 6'):
#                                         com_rand=d77
#                                     elif(com_rand=='Seven of spade 6'):
#                                         com_rand=s77
#                                     elif(com_rand=='Seven of clubs 6'):
#                                         com_rand=c77
#                                     elif(com_rand=='Eight of heart 7'):
#                                         com_rand=h88
#                                     elif(com_rand=='Eight of diamond 7'):
#                                         com_rand=d88
#                                     elif(com_rand=='Eight of spade 7'):
#                                         com_rand=s88
#                                     elif(com_rand=='Eight of clubs 7'):
#                                         com_rand=c88
#                                     elif(com_rand=='Nine of heart 8'):
#                                         com_rand=h99
#                                     elif(com_rand=='Nine of diamond 8'):
#                                         com_rand=d88
#                                     elif(com_rand=='Nine of spade 8'):
#                                         com_rand=s99
#                                     elif(com_rand=='Nine of clubs 8'):
#                                         com_rand=c99
#                                     elif(com_rand=='Ten of heart 9'):
#                                         com_rand=h100
#                                     elif(com_rand=='Ten of diamond 9'):
#                                         com_rand=d100
#                                     elif(com_rand=='Ten of spade 9'):
#                                         com_rand=s100
#                                     elif(com_rand=='Ten of clubs 9'):
#                                         com_rand=c100
#                                     elif(com_rand=='Jack of heart11'):
#                                         com_rand=h1J
#                                     elif(com_rand=='Jack of diamond11'):
#                                         com_rand=d1J
#                                     elif(com_rand=='Jack of spade11'):
#                                         com_rand=s1J
#                                     elif(com_rand=='Jack of clubs11'):
#                                         com_rand=c1J
#                                     elif(com_rand=='Queen of hearts12'):
#                                         com_rand=h1Q
#                                     elif(com_rand=='Queen of diamond12'):
#                                         com_rand=d1Q
#                                     elif(com_rand=='Queen of spade12'):
#                                         com_rand=s1Q
#                                     elif(com_rand=='Queen of clubs12'):
#                                         com_rand=c1Q
#                                     elif(com_rand=='king of heart13'):
#                                         com_rand=h1K
#                                     elif(com_rand=='King of diamond13'):
#                                         com_rand=d1K
#                                     elif(com_rand=='King of spade13'):
#                                         com_rand=s1K
#                                     elif(com_rand=='King of clubs13'):
#                                         com_rand=c1K
#                                     elif(com_rand=='Ace of heart14'):
#                                         com_rand=h1A
#                                     elif(com_rand=='Ace of diamond14'):
#                                         com_rand=d1A
#                                     elif(com_rand=='Ace of spade14'):
#                                         com_rand=s1A
#                                     elif(com_rand=='Ace of clubs14'):
#                                         com_rand=c1A
#                                 if user_rand in user_cards:
#                                     if user_rand=='Two of heart 1':
#                                         user_rand=h22
#                                     elif(user_rand=='Two of diamond 1'):
#                                         user_rand=d22
#                                     elif(user_rand=='Two of spade 1'):
#                                         user_rand=s22
#                                     elif(user_rand=='Two of clubs 1'):
#                                         user_rand=c22
#                                     elif(user_rand=='Three of heart 2'):
#                                         user_rand=h33
#                                     elif(user_rand=='Three of diamond 2'):
#                                         user_rand=d33
#                                     elif(user_rand=='Three of spade 2'):
#                                         user_rand=s33
#                                     elif(user_rand=='Three of clubs 2'):
#                                         user_rand=c33
#                                     elif(user_rand=='Four of heart 3'):
#                                         user_rand=h44
#                                     elif(user_rand=='Four of diamond 3'):
#                                         user_rand=d44
#                                     elif(user_rand=='Four of spade 3'):
#                                         user_rand=s44
#                                     elif(user_rand=='Four of clubs 3'):
#                                         user_rand=c44
#                                     elif(user_rand=='Five of hearts 4'):
#                                         user_rand=h55
#                                     elif(user_rand=='Five of diamond 4'):
#                                         user_rand=d55
#                                     elif(user_rand=='Five of spade 4'):
#                                         user_rand=s55
#                                     elif(user_rand=='Five of clubs 4'):
#                                         user_rand=c55
#                                     elif(user_rand=='Six of heart 5'):
#                                         user_rand=h66
#                                     elif(user_rand=='Six of diamond 5'):
#                                         user_rand=d66
#                                     elif(user_rand=='Six of spade 5'):
#                                         user_rand=s66
#                                     elif(user_rand=='Six of clubs 5'):
#                                         user_rand=c66
#                                     elif(user_rand=='Seven of hearts 6'):
#                                         user_rand=h77
#                                     elif(user_rand=='Seven of diamond 6'):
#                                         user_rand=d77
#                                     elif(user_rand=='Seven of spade 6'):
#                                         user_rand=s77
#                                     elif(user_rand=='Seven of clubs 6'):
#                                         user_rand=c77
#                                     elif(user_rand=='Eight of heart 7'):
#                                         user_rand=h88
#                                     elif(user_rand=='Eight of diamond 7'):
#                                         user_rand=d88
#                                     elif(user_rand=='Eight of spade 7'):
#                                         user_rand=s88
#                                     elif(user_rand=='Eight of clubs 7'):
#                                         user_rand=c88
#                                     elif(user_rand=='Nine of heart 8'):
#                                         user_rand=h99
#                                     elif(user_rand=='Nine of diamond 8'):
#                                         user_rand=d88
#                                     elif(user_rand=='Nine of spade 8'):
#                                         user_rand=s99
#                                     elif(user_rand=='Nine of clubs 8'):
#                                         user_rand=c99
#                                     elif(user_rand=='Ten of heart 9'):
#                                         user_rand=h100
#                                     elif(user_rand=='Ten of diamond 9'):
#                                         user_rand=d100
#                                     elif(user_rand=='Ten of spade 9'):
#                                         user_rand=s100
#                                     elif(user_rand=='Ten of clubs 9'):
#                                         user_rand=c100
#                                     elif(user_rand=='Jack of heart11'):
#                                         user_rand=h1J
#                                     elif(user_rand=='Jack of diamond11'):
#                                         user_rand=d1J
#                                     elif(user_rand=='Jack of spade11'):
#                                         user_rand=s1J
#                                     elif(user_rand=='Jack of clubs11'):
#                                         user_rand=c1J
#                                     elif(user_rand=='Queen of hearts12'):
#                                         user_rand=h1Q
#                                     elif(user_rand=='Queen of diamond12'):
#                                         user_rand=d1Q
#                                     elif(user_rand=='Queen of spade12'):
#                                         user_rand=s1Q
#                                     elif(user_rand=='Queen of clubs12'):
#                                         user_rand=c1Q
#                                     elif(user_rand=='king of heart13'):
#                                         user_rand=h1K
#                                     elif(user_rand=='King of diamond13'):
#                                         user_rand=d1K
#                                     elif(user_rand=='King of spade13'):
#                                         user_rand=s1K
#                                     elif(user_rand=='King of clubs13'):
#                                         user_rand=c1K
#                                     elif(user_rand=='Ace of heart14'):
#                                         user_rand=h1A
#                                     elif(user_rand=='Ace of diamond14'):
#                                         user_rand=d1A
#                                     elif(user_rand=='Ace of spade14'):
#                                         user_rand=s1A
#                                     elif(user_rand=='Ace of clubs14'):
#                                         user_rand=c1A
#                                 comp1 = Label(root,image=com_rand,)
#                                 comp1.grid(row=3,column=1,)
#                                 user1 = Label(root,image =user_rand,)
#                                 user1.grid(row=3,column=3,)
#                                 #user_cards.append(com_rand)
#                                 com_cards.remove(com_rand)
#                         #elif (int(amount)<500):
#                             #messagebox.showinfo('showinfo','number must be greater than 500')
#                         else:
#                             messagebox.showinfo('showinfo','Enter a valid amount')
#
#
#
#                     def claim_amount():
#                         global com_cards
#                         global user_cards
#                         global cards
#                         global sc
#                         global su
#                         global total_amt_com
#                         global total_amt_user
#                         global bc
#                         global bu
#                         global total_amt_user
#                         if sum(total_amt_user)==0:
#                             messagebox.showinfo('showinfo','You didnot win any amount')
#                         elif(sum(total_amt_user)==sum(total_card_comp)):
#                             messagebox.showinfo('showinfo','You Neither win or lose any amount ')
#                         else:
#                             ser=Toplevel()
#                             ser.geometry('420x550')
#                             ser.configure(bg='firebrick3')
#                             ser.resizable(0,0)
#                             def claim_all():
#                                 ser.destroy()
#                                 root.destroy()
#                                 mixer.music.stop()
#
#                             ab=sum(total_amt_user)
#                             text_claim='You win total ₹{}'.format(ab)
#                             back_png= Image.open('casino.png')
#                             back_png= back_png.resize((390, 350), Image.ANTIALIAS)
#                             back_final= ImageTk.PhotoImage(back_png)
#                             backg_label=Label(ser,image=back_final,bg='firebrick3')
#                             backg_label.grid(row=0,column=0,padx=0)
#                             cla_amt=Label(ser,text=text_claim,font=myfont,bg='firebrick3',fg='light goldenrod')
#                             cla_amt.grid(row=1,column=0,ipadx=30)
#                             button_final=Frame(ser,highlightbackground='white',highlightthickness=4,bd=0)
#                             claim_btn_final=Button(button_final,text='Claim',font=myfont,bg='black',fg='light goldenrod',command=claim_all)
#                             claim_btn_final.grid(ipadx=40,ipady=6)
#                             button_final.grid(row=2,column=0,)
#                             mixer.music.load('Money_Counter_SFX.wav')
#                             mixer.music.play(1)
#                             ser.mainloop()
#
#                     def on_click(event):
#                         global com_cards
#                         global user_cards
#                         global cards
#                         global sc
#                         global su
#                         global total_amt_com
#                         global total_amt_user
#                         global bc
#                         global bu
#                         my_entry.configure(state=NORMAL)
#                         my_entry.delete(0,END)
#
#                         my_entry.unbind('<Button-1>',on_click_id)
#
#                     my_entry=Entry(root,width=40,fg='light goldenrod',bg='black',font=10)
#                     my_entry.grid(row=1,column=2,padx=40,pady=15,ipady=10)
#                     my_entry.insert(0,'Enter the Amount you like to bet',)
#                     my_entry.configure(state=DISABLED,)
#                     on_click_id=my_entry.bind('<Button-1>',on_click)
#
#                     comp=Label(root,text='Computer',fg='light goldenrod',bg='black',font=myfont)
#                     comp.grid(row=2,column=1,padx=40,pady=10)
#                     user=Label(root,text='User',fg='light goldenrod',bg='black',font=myfont)
#                     user.grid(row=2,column=3,padx=40,pady=10)
#                     backc= Image.open('yellow_back.png')
#                     backc= backc.resize((150, 200), Image.ANTIALIAS)
#                     bc= ImageTk.PhotoImage(backc)
#
#                     backu= Image.open('red_back.png')
#                     backu= backu.resize((150, 200), Image.ANTIALIAS)
#                     bu= ImageTk.PhotoImage(backu)
#
#                     comp1 = Label(root,image =bc)
#                     comp1.grid(row=3,column=1,)
#                     user1 = Label(root,image =bu)
#                     user1.grid(row=3,column=3,)
#                     button_border=Frame(root,highlightbackground='white',highlightthickness=4,bd=0)
#                     but=Button(button_border,text='Show Cards',bg='light goldenrod',fg='black',font=myfont,command=play)
#                     but.grid()
#                     button_border.grid(row=4,column=2,pady=20,padx=30)
#                     totalc=Label(root,text='Total Wins computer:',fg='light goldenrod',bg='black',font=myfont)
#                     totalc.grid(row=5,column=1,padx=40,pady=20)
#                     border=Frame(root,highlightbackground='white',highlightthickness=3,bd=0)
#                     claim=Button(border,text='Claim winning amount',fg='light goldenrod',bg='red',command=claim_amount)
#                     claim.grid(ipady=10)
#                     border.grid(row=5,column=2,pady=20,)
#                     totalu=Label(root,text='Total Wins user:',fg='light goldenrod',bg='black',font=myfont)
#                     totalu.grid(row=5,column=3,padx=40,pady=20)
#                     compc=Label(root,text='0',bg='black',fg='light goldenrod',font=myfont)
#                     compc.grid(row=6,column=1,padx=40,pady=10)
#                     userc=Label(root,text='0',bg='black',fg='light goldenrod',font=myfont)
#                     userc.grid(row=6,column=3,padx=40,pady=10)
#
#
#                     mixer.music.load('background_music.mp3')
#                     mixer.music.play(1)
#
#                     root.mainloop()
#
#
#
#             def decline():
#                 inst.destroy()
#                 window.destroy()
#
#             myfont=font.Font(family='Stencil Std',size=16)
#             inst_text=Label(inst,font=myfont,bg='light goldenrod',text='Note-This game is little  diffrent  from original card  war game ,\n we made  little changes to make this game little intresting. \n INSTRUCTIONS \n -->From deck of 52 cards game will divide 26 cards  to each \n player  and  any random  card  will come  from  deck  of 26  \n cards. \n --> you have to first Bet the amount greater than 500 rupees.  \n-->If user card rank is greater than computer card rank then \n you will win bet amount \n--> If Computer card rank is greater than your  card  Rank  \n then you lose your bet amount \n --> If Both player have same card then it will be WAR!! and \n in war  from both players deck any 5 random cards will \n  pick and any random card will shown after clicking show \n card button  \n--> If user win War Round User will Win All amount which he \n/she lose till now \n -->If computer win War round computer  will  win all amount \n which user win till now \n --> if Tie Agian neither user neither computer will any  amount \n game  will continue as earlier \n --> TO cliam win Amount press cliam win amount Button on \n screen  ')
#             inst_text.grid(row=0,column=1)
#             ch_accept=Checkbutton(inst,text='Accept',variable=chech_check,font=20)
#             ch_accept.grid(row=1,column=1)
#             agree=Button(inst,text='Agree',command=move_fur,bg='green',fg='light goldenrod')
#             agree.grid(row=3,column=1,ipadx=30,ipady=10)
#             decline=Button(inst,text='Decline',bg='red',fg='light goldenrod',command=decline)
#             decline.grid(row=4,column=1,ipadx=30,ipady=10,pady=15)
#             inst.mainloop()
#     except :
#         messagebox.showinfo('showinfo','enter a valid input')
#
# window.geometry('700x600')
# window.configure(bg='black')
# window.resizable(0,0)
# welco=Label(window,text='Card war game!!',font=myfont,fg='light goldenrod',bg='black')
# welco.grid(row=0,column=1,ipadx=35,ipady=10)
# naml=Label(window,text='Name',bg='light goldenrod',font=myfont)
# naml.grid(row=1,column=0,padx=10,)
# name=Entry(window,bg='white',font=myfont)
# name.grid(row=1,column=1,ipadx=30,padx=10,pady=20)
# play=Button(window,text='play',bg='light goldenrod',fg='black',font=myfont,command=front_page)
# play.grid(row=2,column=1,pady=20,ipadx=30)
# image1 = Image.open('mainwalp.png')
# # The (450, 350) is (height, width)
# image1 = image1.resize((300, 200), Image.ANTIALIAS)
# my_img = ImageTk.PhotoImage(image1)
# my_img1 = Label(window,image = my_img,bg='black')
# my_img1.grid(row=3,column=1,padx=10,pady=20)
#
# mixer.music.load('enter_sound.mp3')
# mixer.music.play(1)
# window.mainloop()
